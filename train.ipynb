# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from utils import *
from tqdm import tqdm
import argparse
import multiprocessing as mp

# %%
import sys; sys.argv=['']; del sys
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=UserWarning)
if os.path.exists('./best_model.pt'):
    print('Remove last time training files')
    os.remove('./best_model.pt')
# Out:
# Remove last time training files

# %%
parser = argparse.ArgumentParser(description='Training GCN on Cora/CiteSeer/PubMed/Reddit Datasets')

'''
    Dataset arguments
'''
parser.add_argument('--dataset', type=str, default='cora',
                    help='Dataset name: cora/citeseer/pubmed/reddit')
parser.add_argument('--nhid', type=int, default=256,
                    help='Hidden state dimension')
parser.add_argument('--epoch_num', type=int, default= 100,
                    help='Number of Epoch')
parser.add_argument('--pool_num', type=int, default= 10,
                    help='Number of Pool')
parser.add_argument('--batch_num', type=int, default= 10,
                    help='Maximum Batch Number')
parser.add_argument('--batch_size', type=int, default=512,
                    help='size of output node in a batch')
parser.add_argument('--n_layers', type=int, default=2, # in ladies they use 5
                    help='Number of GCN layers')
parser.add_argument('--n_iters', type=int, default=2,
                    help='Number of iteration to run on a batch')
parser.add_argument('--n_stops', type=int, default=200,
                    help='Stop after number of batches that f1 dont increase')
parser.add_argument('--samp_num', type=int, default=512, #512 as default for layer-wise, 5 as default for node-wise
                    help='Number of sampled nodes per layer')
parser.add_argument('--sample_method', type=str, default='fastgcn',
                    help='Sampled Algorithms: ladies/fastgcn/graphsage/full')
parser.add_argument('--cuda', type=int, default=1,
                    help='Avaiable GPU ID')
parser.add_argument('--variance_reduction', type=bool, default=False,
                    help='Apply variance reduction')
# Out:
# _StoreAction(option_strings=['--variance_reduction'], dest='variance_reduction', nargs=None, const=None, default=False, type=<class 'bool'>, choices=None, help='Apply variance reduction', metavar=None)

# %%
args = parser.parse_args()
print(args)
# Out:
# Namespace(batch_num=10, batch_size=512, cuda=1, dataset='cora', epoch_num=100, n_iters=2, n_layers=2, n_stops=200, nhid=256, pool_num=10, samp_num=512, sample_method='fastgcn', variance_reduction=False)

# %%
class GraphConvolution(nn.Module):
    def __init__(self, n_in, n_out, num_nodes):
        super(GraphConvolution, self).__init__()
        self.n_in  = n_in
        self.n_out = n_out
        self.linear = nn.Linear(n_in,  n_out)
        self.snapshot = torch.zeros([num_nodes, n_out], dtype=torch.float32)
        self.timer = torch.zeros([num_nodes, 1], dtype=torch.float32)
        self.c = 0.3
        
    def forward(self, x, adj, sampled_nodes, ell):
        x = self.linear(x)
        x = torch.spmm(adj, x)
        if self.training and args.variance_reduction:
            snapshot_sampled = self.snapshot[sampled_nodes,:].to(x)
            momentum = 1-self.exp_ata_weight(self.timer[sampled_nodes,:])
#             momentum = 1/torch.pow(self.timer[sampled_nodes,:]+1, 1/(1+args.n_layers))
#             x = x+(1-momentum.to(x))*(snapshot_sampled - x.detach())
            x = momentum.to(x) * x + (1-momentum.to(x)) * snapshot_sampled
            self.snapshot[sampled_nodes, :] = x.detach().cpu()
            self.timer[sampled_nodes, :] += 1
        return F.elu(x)
    
    def exp_ata_weight(self, num_steps):
        mask = num_steps < 2
        num_steps[mask]=2 # to get rid of the warning 1/0
        gamma = self.c * num_steps / (1.0 + self.c * num_steps)
        gamma *= 1.0 - torch.sqrt((1.0 - self.c) / (num_steps * (num_steps + 1))) / self.c
        gamma[mask] = 0
        return gamma
    
class GCN(nn.Module):
    def __init__(self, nfeat, nhid, layers, dropout, num_nodes):
        super(GCN, self).__init__()
        self.layers = layers
        self.nhid = nhid
        self.gcs = nn.ModuleList()
        self.gcs.append(GraphConvolution(nfeat,  nhid, num_nodes))
        self.dropout = nn.Dropout(dropout)
        for i in range(layers-1):
            self.gcs.append(GraphConvolution(nhid,  nhid, num_nodes))
    def forward(self, x, adjs, sampled_nodes):
        for ell in range(len(self.gcs)):
            x = self.gcs[ell](x, adjs[ell], sampled_nodes[ell], ell)
            x = self.dropout(x)
        return x 
    
class SuGCN(nn.Module):
    def __init__(self, encoder, num_classes, dropout, inp, num_nodes):
        super(SuGCN, self).__init__()
        self.encoder = encoder
        self.dropout = nn.Dropout(dropout)
        self.linear  = nn.Linear(self.encoder.nhid, num_classes)
    def forward(self, feat, adjs, sampled_nodes):
        x = self.encoder(feat, adjs, sampled_nodes)
        x = self.linear(x)
        return F.log_softmax(x, dim=1)

# %%
def fastgcn_sampler(seed, batch_nodes, samp_num_list, num_nodes, lap_matrix, lap_matrix_sq, depth):    
    np.random.seed(seed)
    previous_nodes = batch_nodes
    sampled_nodes = []
    adjs  = []
    pi = np.array(np.sum(lap_matrix_sq, axis=0))[0]
    p = pi / np.sum(pi)
    for d in range(depth):
        U = lap_matrix[previous_nodes , :]
        s_num = np.min([np.sum(p > 0), samp_num_list[d]])
        after_nodes = np.random.choice(num_nodes, s_num, p = p, replace = False)
        adj = U[: , after_nodes].multiply(1/p[after_nodes])
        adjs += [sparse_mx_to_torch_sparse_tensor(row_normalize(adj))]
        sampled_nodes += [previous_nodes]
        previous_nodes = after_nodes
    sampled_nodes.reverse()
    adjs.reverse()
    return adjs, previous_nodes, batch_nodes, sampled_nodes

def ladies_sampler(seed, batch_nodes, samp_num_list, num_nodes, lap_matrix, lap_matrix_sq, depth):
    np.random.seed(seed)
    previous_nodes = batch_nodes
    sampled_nodes = []
    adjs  = []
    for d in range(depth):
        U = lap_matrix[previous_nodes , :]
        pi = np.array(np.sum(lap_matrix_sq[previous_nodes , :], axis=0))[0]
        p = pi / np.sum(pi)
        s_num = np.min([np.sum(p > 0), samp_num_list[d]])
        after_nodes = np.random.choice(num_nodes, s_num, p = p, replace = False)
        after_nodes = np.unique(np.concatenate((after_nodes, batch_nodes)))
        adj = U[: , after_nodes].multiply(1/p[after_nodes])
        adjs += [sparse_mx_to_torch_sparse_tensor(row_normalize(adj))]
        sampled_nodes += [previous_nodes]
        previous_nodes = after_nodes
    sampled_nodes.reverse()
    adjs.reverse()
    return adjs, previous_nodes, batch_nodes, sampled_nodes

# def full_sampler(seed, batch_nodes, samp_num_list, num_nodes, lap_matrix, lap_matrix_sq, depth):
#     previous_nodes = batch_nodes
#     sampled_nodes = []
#     adjs = []
#     for d in range(depth):
#         # print(previous_nodes)
#         U = lap_matrix[previous_nodes, :]
#         pi = np.sum(U, axis=0)
#         indices = np.where(pi > 0)[1]
#         after_nodes = np.unique(np.concatenate((indices, batch_nodes)))
#         adj = U[:, after_nodes]
#         adjs += [sparse_mx_to_torch_sparse_tensor(adj)]
#         previous_nodes = after_nodes
#         sampled_nodes.append(after_nodes)
#     adjs.reverse()
#     sampled_nodes.reverse()
#     return adjs, previous_nodes, batch_nodes, sampled_nodes

def full_sampler(seed, batch_nodes, samp_num_list, num_nodes, lap_matrix, lap_matrix_sq, depth):
    sampled_nodes = [np.arange(num_nodes) for d in range(depth)]
    adjs = []
    for d in range(depth-1):
        adjs += [sparse_mx_to_torch_sparse_tensor(lap_matrix)]
    adjs += [sparse_mx_to_torch_sparse_tensor(lap_matrix[batch_nodes])]
    return adjs, np.arange(num_nodes), batch_nodes, sampled_nodes

def graphsage_sampler(seed, batch_nodes, samp_num_list, num_nodes, lap_matrix, lap_matrix_sq, depth):
    sampled_nodes = []
    previous_nodes = batch_nodes
    adjs = []
    for d in range(depth):
        U = lap_matrix[previous_nodes , :]
        pi = np.sum(U, axis=0).flatten()
        indices = np.where(pi > 0)[0]
        after_nodes = np.random.choice(indices, samp_num_list[d], replace=True)
        after_nodes = np.unique(np.concatenate((after_nodes, batch_nodes)))
        adj = U[:, after_nodes]
        adjs += [sparse_mx_to_torch_sparse_tensor(row_normalize(adj))]
        sampled_nodes.append(previous_nodes)
        previous_nodes = after_nodes
    adjs.reverse()
    sampled_nodes.reverse()
    return adjs, previous_nodes, batch_nodes, sampled_nodes

def default_sampler(seed, batch_nodes, samp_num_list, num_nodes, lap_matrix, lap_matrix_sq, depth):
    mx = sparse_mx_to_torch_sparse_tensor(lap_matrix)
    return [mx for i in range(depth)], np.arange(num_nodes), batch_nodes, np.arange(num_nodes)

def prepare_data(pool, sampler, process_ids, train_nodes, valid_nodes, samp_num_list, num_nodes, lap_matrix, lap_matrix_sq, depth):
    
    jobs = []
    for _ in process_ids:
        idx = torch.randperm(len(train_nodes))[:args.batch_size]
        batch_nodes = train_nodes[idx]
        p = pool.apply_async(sampler, args=(np.random.randint(2**32 - 1), batch_nodes,                                                    
                                            samp_num_list, num_nodes, lap_matrix, lap_matrix_sq, depth))
        jobs.append(p)
    idx = torch.randperm(len(valid_nodes))[:args.batch_size]
    batch_nodes = valid_nodes[idx]
    p = pool.apply_async(sampler, args=(np.random.randint(2**32 - 1), batch_nodes,                                                
                                        samp_num_list * 20, num_nodes, lap_matrix, lap_matrix_sq, depth))
    jobs.append(p)
    return jobs

def package_mxl(mxl, device):
    return [torch.sparse.FloatTensor(mx[0], mx[1], mx[2]).to(device) for mx in mxl]

# %%
if args.cuda != -1:
    device = torch.device("cuda:" + str(args.cuda))
else:
    device = torch.device("cpu")
    
edges, labels, feat_data, train_nodes, valid_nodes, test_nodes = preprocess_data(args.dataset)
print(edges.shape, labels.shape, feat_data.shape, train_nodes.shape, valid_nodes.shape, test_nodes.shape)
# Out:
# (10556, 2) (2708,) (2708, 1433) (1208,) (500,) (1000,)

# %%
num_classes = labels.max().item()+1

# %%
adj_matrix = get_adj(edges, feat_data.shape[0])
lap_matrix = normalize(adj_matrix + sp.eye(adj_matrix.shape[0]))
lap_matrix_sq = lap_matrix.multiply(lap_matrix)

if type(feat_data) == sp.lil.lil_matrix:
    feat_data = torch.FloatTensor(feat_data.todense()).to(device) 
else:
    feat_data = torch.FloatTensor(feat_data).to(device)
labels    = torch.LongTensor(labels).to(device)

# %%
if args.sample_method == 'ladies':
    sampler = ladies_sampler
    samp_num_list = np.array([args.samp_num for _ in range(args.n_layers)])
elif args.sample_method == 'fastgcn':
    sampler = fastgcn_sampler
    samp_num_list = np.array([args.samp_num for _ in range(args.n_layers)])
elif args.sample_method == 'full':
    sampler = full_sampler
    samp_num_list = np.array([args.samp_num for _ in range(args.n_layers)])
elif args.sample_method == 'graphsage':
    sampler = graphsage_sampler
    samp_num_list = np.array([args.batch_size*args.samp_num**i for i in range(args.n_layers)])

# %%
process_ids = np.arange(args.batch_num)

pool = mp.Pool(args.pool_num)
jobs = prepare_data(pool, sampler, process_ids, train_nodes, valid_nodes, samp_num_list, len(feat_data), lap_matrix, lap_matrix_sq, args.n_layers)

all_res = []
encoder = GCN(nfeat = feat_data.shape[1], nhid=args.nhid, layers=args.n_layers, dropout = 0.2, num_nodes=feat_data.shape[0]).to(device)
susage  = SuGCN(encoder = encoder, num_classes=num_classes, dropout=0.5, inp = feat_data.shape[1], num_nodes=feat_data.shape[0])
susage.to(device)

print(susage)

optimizer = optim.Adam(filter(lambda p : p.requires_grad, susage.parameters()))
best_val = 0
best_tst = -1
times = []
res   = []
train_losses_all = []
for oiter in range(5):
    cnt = 0
    print('-' * 10)
    for epoch in np.arange(args.epoch_num):
        susage.train()
        train_losses = []
        train_data = [job.get() for job in jobs[:-1]]
        valid_data = jobs[-1].get()
        pool.close()
        pool.join()
        pool = mp.Pool(args.pool_num)
        jobs = prepare_data(pool, sampler, process_ids, train_nodes, valid_nodes, samp_num_list, len(feat_data), lap_matrix, lap_matrix_sq, args.n_layers)
        for _iter in range(args.n_iters):
            for adjs, input_nodes, output_nodes, sampled_nodes in train_data:   
                adjs = package_mxl(adjs, device)
                optimizer.zero_grad()
                t1 = time.time()
                susage.train()
                output = susage.forward(feat_data[input_nodes], adjs, sampled_nodes)
                loss_train = F.nll_loss(output, labels[output_nodes])
                loss_train.backward()
                torch.nn.utils.clip_grad_norm_(susage.parameters(), 0.2)
                optimizer.step()
                times += [time.time() - t1]
                train_losses += [loss_train.detach().tolist()]
                del loss_train
        susage.eval()
        adjs, input_nodes, output_nodes, sampled_nodes = valid_data
        adjs = package_mxl(adjs, device)
        output = susage.forward(feat_data[input_nodes], adjs, sampled_nodes)
        loss_valid = F.nll_loss(output, labels[output_nodes]).detach().tolist()
        valid_f1 = f1_score(output.argmax(dim=1).cpu(), labels[output_nodes].cpu(), average='micro')
        print(("Epoch: %d (%.1fs) Train Loss: %.2f    Valid Loss: %.2f Valid F1: %.3f") %                   
              (epoch, np.sum(times), np.average(train_losses), loss_valid, valid_f1))
        train_losses_all.extend(train_losses)
        if valid_f1 > best_val:
            torch.save(susage, './best_model.pt')
        if valid_f1 > best_val + 1e-2:
            best_val = valid_f1
            cnt = 0
        else:
            cnt += 1
        if cnt > args.n_stops // args.batch_num:
            break
    best_model = torch.load('./best_model.pt')
    best_model.eval()
    test_f1s = []
    for b in np.arange(len(test_nodes) // args.batch_size):
        batch_nodes = test_nodes[b * args.batch_size : (b+1) * args.batch_size]
        adjs, input_nodes, output_nodes, sampled_nodes = sampler(np.random.randint(2**32 - 1), batch_nodes,
                                    samp_num_list * 20, len(feat_data), lap_matrix, lap_matrix_sq, args.n_layers)
        adjs = package_mxl(adjs, device)
        output = best_model.forward(feat_data[input_nodes], adjs, sampled_nodes)
        loss_test = F.nll_loss(output, labels[output_nodes]).cpu().detach().tolist()
        test_f1 = f1_score(output.argmax(dim=1).cpu(), labels[output_nodes].cpu(), average='micro')
        test_f1s += [test_f1]
    print('Iteration: %d, Test F1: %.3f' % (oiter, np.average(test_f1)))
# Out:
# SuGCN(
#   (encoder): GCN(
#     (gcs): ModuleList(
#       (0): GraphConvolution(
#         (linear): Linear(in_features=1433, out_features=256, bias=True)
#       )
#       (1): GraphConvolution(
#         (linear): Linear(in_features=256, out_features=256, bias=True)
#       )
#     )
#     (dropout): Dropout(p=0.2)
#   )
#   (dropout): Dropout(p=0.5)
#   (linear): Linear(in_features=256, out_features=7, bias=True)
# )
# ----------
# Epoch: 0 (0.6s) Train Loss: 1.82    Valid Loss: 1.34 Valid F1: 0.496
# Epoch: 1 (0.7s) Train Loss: 1.42    Valid Loss: 0.62 Valid F1: 0.738
# Epoch: 2 (0.9s) Train Loss: 0.98    Valid Loss: 0.62 Valid F1: 0.826
# Epoch: 3 (1.1s) Train Loss: 0.71    Valid Loss: 0.55 Valid F1: 0.850
# Epoch: 4 (1.2s) Train Loss: 0.53    Valid Loss: 0.54 Valid F1: 0.858
# Epoch: 5 (1.3s) Train Loss: 0.47    Valid Loss: 0.56 Valid F1: 0.882
# Epoch: 6 (1.5s) Train Loss: 0.40    Valid Loss: 0.58 Valid F1: 0.876
# Epoch: 7 (1.6s) Train Loss: 0.37    Valid Loss: 0.60 Valid F1: 0.878
# Epoch: 8 (1.8s) Train Loss: 0.32    Valid Loss: 0.62 Valid F1: 0.868
# Epoch: 9 (2.0s) Train Loss: 0.29    Valid Loss: 0.66 Valid F1: 0.870
# Epoch: 10 (2.1s) Train Loss: 0.28    Valid Loss: 0.71 Valid F1: 0.868
# Epoch: 11 (2.3s) Train Loss: 0.27    Valid Loss: 0.75 Valid F1: 0.868
# Epoch: 12 (2.5s) Train Loss: 0.24    Valid Loss: 0.73 Valid F1: 0.874
# Epoch: 13 (2.6s) Train Loss: 0.25    Valid Loss: 0.73 Valid F1: 0.876
# Epoch: 14 (2.8s) Train Loss: 0.24    Valid Loss: 0.75 Valid F1: 0.878
# Epoch: 15 (2.9s) Train Loss: 0.23    Valid Loss: 0.79 Valid F1: 0.874
# Epoch: 16 (3.1s) Train Loss: 0.21    Valid Loss: 0.82 Valid F1: 0.876
# Epoch: 17 (3.3s) Train Loss: 0.20    Valid Loss: 0.84 Valid F1: 0.876
# Epoch: 18 (3.4s) Train Loss: 0.20    Valid Loss: 0.85 Valid F1: 0.882
# Epoch: 19 (3.6s) Train Loss: 0.19    Valid Loss: 0.85 Valid F1: 0.878
# Epoch: 20 (3.7s) Train Loss: 0.18    Valid Loss: 0.88 Valid F1: 0.878
# Epoch: 21 (3.9s) Train Loss: 0.16    Valid Loss: 0.90 Valid F1: 0.874
# Epoch: 22 (4.0s) Train Loss: 0.17    Valid Loss: 0.89 Valid F1: 0.882
# Epoch: 23 (4.2s) Train Loss: 0.17    Valid Loss: 0.90 Valid F1: 0.880
# Epoch: 24 (4.3s) Train Loss: 0.17    Valid Loss: 0.90 Valid F1: 0.878
# Epoch: 25 (4.5s) Train Loss: 0.17    Valid Loss: 0.91 Valid F1: 0.884
# Epoch: 26 (4.6s) Train Loss: 0.17    Valid Loss: 0.91 Valid F1: 0.886
# Iteration: 0, Test F1: 0.842
# ----------
# Epoch: 0 (4.8s) Train Loss: 0.16    Valid Loss: 0.93 Valid F1: 0.876
# Epoch: 1 (5.0s) Train Loss: 0.16    Valid Loss: 0.95 Valid F1: 0.872
# Epoch: 2 (5.1s) Train Loss: 0.16    Valid Loss: 0.96 Valid F1: 0.868
# Epoch: 3 (5.3s) Train Loss: 0.16    Valid Loss: 0.98 Valid F1: 0.864
# Epoch: 4 (5.4s) Train Loss: 0.14    Valid Loss: 0.99 Valid F1: 0.862
# Epoch: 5 (5.6s) Train Loss: 0.15    Valid Loss: 1.00 Valid F1: 0.870
# Epoch: 6 (5.8s) Train Loss: 0.14    Valid Loss: 1.02 Valid F1: 0.870
# Epoch: 7 (5.9s) Train Loss: 0.14    Valid Loss: 1.04 Valid F1: 0.870
# Epoch: 8 (6.1s) Train Loss: 0.13    Valid Loss: 1.04 Valid F1: 0.874
# Epoch: 9 (6.2s) Train Loss: 0.13    Valid Loss: 1.07 Valid F1: 0.870
# Epoch: 10 (6.4s) Train Loss: 0.13    Valid Loss: 1.11 Valid F1: 0.868
# Epoch: 11 (6.5s) Train Loss: 0.12    Valid Loss: 1.11 Valid F1: 0.872
# Epoch: 12 (6.7s) Train Loss: 0.12    Valid Loss: 1.14 Valid F1: 0.868
# Epoch: 13 (6.8s) Train Loss: 0.11    Valid Loss: 1.15 Valid F1: 0.868
# Epoch: 14 (7.0s) Train Loss: 0.12    Valid Loss: 1.17 Valid F1: 0.874
# Epoch: 15 (7.1s) Train Loss: 0.12    Valid Loss: 1.19 Valid F1: 0.870
# Epoch: 16 (7.3s) Train Loss: 0.12    Valid Loss: 1.20 Valid F1: 0.872
# Epoch: 17 (7.5s) Train Loss: 0.12    Valid Loss: 1.19 Valid F1: 0.870
# Epoch: 18 (7.6s) Train Loss: 0.11    Valid Loss: 1.21 Valid F1: 0.872
# Epoch: 19 (7.8s) Train Loss: 0.11    Valid Loss: 1.22 Valid F1: 0.874
# Epoch: 20 (7.9s) Train Loss: 0.11    Valid Loss: 1.23 Valid F1: 0.870
# Iteration: 1, Test F1: 0.842
# ----------
# Epoch: 0 (8.1s) Train Loss: 0.12    Valid Loss: 1.27 Valid F1: 0.868
# Epoch: 1 (8.2s) Train Loss: 0.11    Valid Loss: 1.29 Valid F1: 0.870
# Epoch: 2 (8.4s) Train Loss: 0.10    Valid Loss: 1.29 Valid F1: 0.868
# Epoch: 3 (8.5s) Train Loss: 0.12    Valid Loss: 1.30 Valid F1: 0.870
# Epoch: 4 (8.7s) Train Loss: 0.11    Valid Loss: 1.32 Valid F1: 0.866
# Epoch: 5 (8.8s) Train Loss: 0.10    Valid Loss: 1.33 Valid F1: 0.866
# Epoch: 6 (9.0s) Train Loss: 0.10    Valid Loss: 1.34 Valid F1: 0.866
# Epoch: 7 (9.2s) Train Loss: 0.10    Valid Loss: 1.34 Valid F1: 0.866
# Epoch: 8 (9.3s) Train Loss: 0.10    Valid Loss: 1.36 Valid F1: 0.866
# Epoch: 9 (9.5s) Train Loss: 0.09    Valid Loss: 1.38 Valid F1: 0.870
# Epoch: 10 (9.7s) Train Loss: 0.10    Valid Loss: 1.36 Valid F1: 0.866
# Epoch: 11 (9.8s) Train Loss: 0.10    Valid Loss: 1.38 Valid F1: 0.870
# Epoch: 12 (10.0s) Train Loss: 0.10    Valid Loss: 1.40 Valid F1: 0.872
# Epoch: 13 (10.1s) Train Loss: 0.09    Valid Loss: 1.43 Valid F1: 0.874
# Epoch: 14 (10.2s) Train Loss: 0.09    Valid Loss: 1.42 Valid F1: 0.868
# Epoch: 15 (10.4s) Train Loss: 0.09    Valid Loss: 1.43 Valid F1: 0.868
# Epoch: 16 (10.6s) Train Loss: 0.08    Valid Loss: 1.44 Valid F1: 0.866
# Epoch: 17 (10.7s) Train Loss: 0.08    Valid Loss: 1.46 Valid F1: 0.866
# Epoch: 18 (10.9s) Train Loss: 0.09    Valid Loss: 1.47 Valid F1: 0.864
# Epoch: 19 (11.0s) Train Loss: 0.08    Valid Loss: 1.48 Valid F1: 0.868
# Epoch: 20 (11.2s) Train Loss: 0.09    Valid Loss: 1.49 Valid F1: 0.866
# Iteration: 2, Test F1: 0.842
# ----------
# Epoch: 0 (11.3s) Train Loss: 0.09    Valid Loss: 1.49 Valid F1: 0.866
# Epoch: 1 (11.5s) Train Loss: 0.08    Valid Loss: 1.51 Valid F1: 0.872
# Epoch: 2 (11.6s) Train Loss: 0.08    Valid Loss: 1.50 Valid F1: 0.872
# Epoch: 3 (11.8s) Train Loss: 0.09    Valid Loss: 1.50 Valid F1: 0.872
# Epoch: 4 (12.0s) Train Loss: 0.08    Valid Loss: 1.50 Valid F1: 0.874
# Epoch: 5 (12.1s) Train Loss: 0.08    Valid Loss: 1.54 Valid F1: 0.874
# Epoch: 6 (12.3s) Train Loss: 0.08    Valid Loss: 1.55 Valid F1: 0.872
# Epoch: 7 (12.5s) Train Loss: 0.08    Valid Loss: 1.57 Valid F1: 0.872
# Epoch: 8 (12.6s) Train Loss: 0.08    Valid Loss: 1.60 Valid F1: 0.866
# Epoch: 9 (12.8s) Train Loss: 0.08    Valid Loss: 1.60 Valid F1: 0.868
# Epoch: 10 (13.0s) Train Loss: 0.07    Valid Loss: 1.61 Valid F1: 0.868
# Epoch: 11 (13.1s) Train Loss: 0.07    Valid Loss: 1.63 Valid F1: 0.870
# Epoch: 12 (13.3s) Train Loss: 0.07    Valid Loss: 1.65 Valid F1: 0.868
# Epoch: 13 (13.4s) Train Loss: 0.07    Valid Loss: 1.63 Valid F1: 0.870
# Epoch: 14 (13.6s) Train Loss: 0.07    Valid Loss: 1.66 Valid F1: 0.868
# Epoch: 15 (13.8s) Train Loss: 0.07    Valid Loss: 1.72 Valid F1: 0.858
# Epoch: 16 (13.9s) Train Loss: 0.07    Valid Loss: 1.74 Valid F1: 0.856
# Epoch: 17 (14.1s) Train Loss: 0.07    Valid Loss: 1.76 Valid F1: 0.852
# Epoch: 18 (14.2s) Train Loss: 0.07    Valid Loss: 1.75 Valid F1: 0.856
# Epoch: 19 (14.4s) Train Loss: 0.07    Valid Loss: 1.75 Valid F1: 0.856
# Epoch: 20 (14.5s) Train Loss: 0.07    Valid Loss: 1.79 Valid F1: 0.854
# Iteration: 3, Test F1: 0.842
# ----------
# Epoch: 0 (14.7s) Train Loss: 0.07    Valid Loss: 1.79 Valid F1: 0.856
# Epoch: 1 (14.8s) Train Loss: 0.07    Valid Loss: 1.82 Valid F1: 0.856
# Epoch: 2 (15.0s) Train Loss: 0.07    Valid Loss: 1.84 Valid F1: 0.854
# Epoch: 3 (15.1s) Train Loss: 0.07    Valid Loss: 1.83 Valid F1: 0.852
# Epoch: 4 (15.3s) Train Loss: 0.07    Valid Loss: 1.89 Valid F1: 0.850
# Epoch: 5 (15.5s) Train Loss: 0.07    Valid Loss: 1.93 Valid F1: 0.856
# Epoch: 6 (15.6s) Train Loss: 0.07    Valid Loss: 1.93 Valid F1: 0.854
# Epoch: 7 (15.8s) Train Loss: 0.07    Valid Loss: 1.89 Valid F1: 0.860
# Epoch: 8 (15.9s) Train Loss: 0.07    Valid Loss: 1.90 Valid F1: 0.858
# Epoch: 9 (16.1s) Train Loss: 0.06    Valid Loss: 1.91 Valid F1: 0.862
# Epoch: 10 (16.3s) Train Loss: 0.07    Valid Loss: 1.93 Valid F1: 0.860
# Epoch: 11 (16.4s) Train Loss: 0.07    Valid Loss: 1.95 Valid F1: 0.858
# Epoch: 12 (16.6s) Train Loss: 0.06    Valid Loss: 1.94 Valid F1: 0.860
# Epoch: 13 (16.7s) Train Loss: 0.06    Valid Loss: 1.91 Valid F1: 0.860
# Epoch: 14 (16.9s) Train Loss: 0.06    Valid Loss: 1.88 Valid F1: 0.862
# Epoch: 15 (17.0s) Train Loss: 0.07    Valid Loss: 1.92 Valid F1: 0.858
# Epoch: 16 (17.2s) Train Loss: 0.06    Valid Loss: 1.95 Valid F1: 0.860
# Epoch: 17 (17.3s) Train Loss: 0.06    Valid Loss: 1.94 Valid F1: 0.864
# Epoch: 18 (17.5s) Train Loss: 0.06    Valid Loss: 1.94 Valid F1: 0.862
# Epoch: 19 (17.6s) Train Loss: 0.06    Valid Loss: 2.02 Valid F1: 0.856
# Epoch: 20 (17.8s) Train Loss: 0.06    Valid Loss: 2.02 Valid F1: 0.854
# Iteration: 4, Test F1: 0.842

# %%
with open('{}-vr.pkl'.format(args.sample_method),'wb') as f:
    pkl.dump(train_losses_all, f)

# %%
import matplotlib.pyplot as plt
sample_methods = ['full','ladies','fastgcn','graphsage','ladies-vr','fastgcn-vr','graphsage-vr']
fig, axs = plt.subplots()
for method in sample_methods:
    with open('{}.pkl'.format(method),'rb') as f:
        loss = pkl.load(f)
        loss = loss[:400]
        x = np.arange(len(loss))
        axs.plot(x,loss,label=method)
        
axs.set_xlabel('iters')
axs.set_ylabel('loss')
axs.grid(True)

fig.tight_layout()
plt.legend()
plt.savefig('train_loss_cora.pdf')

# %%
if 1:
    print(True)
#     with open('{}-vr.pkl'.format(args.sample_method),'wb') as f:
#         pkl.dump(train_losses_all, f)
else:
    print(False)
#     with open('{}.pkl'.format(args.sample_method),'wb') as f:
#         pkl.dump(train_losses_all, f)
# Out:
# True
